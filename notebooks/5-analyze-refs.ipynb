# %%
import pandas as pd

# Caminho para o arquivo CSV
caminho_csv = "../data/processed/refs.csv"

# Lê o arquivo CSV em um DataFrame
refs_df = pd.read_csv(caminho_csv)

refs_df.head()
# Out:
#    Unnamed: 0  paper_id                raw  \
# 0           0         1  Streissler (1972)
# 1           1         1    (Menger, [1981]
# 2           2         1       1871, p. 49)
# 3           3         1    (Menger, [1981]
# 4           4         1     Menger's (1985
#
#                                              context sentence_id  \
# 0  In particular, as the classic contributions of...    _TMX2wdg
# 1  The final two paragraphs of the preface are a ...    _aJz9uAb
# 2  The final two paragraphs of the preface are a ...    _aJz9uAb
# 3  He also goes to some length in the preface to ...    _54sgkMV
# 4  A detour into Menger's (1985Menger's ( [1883] ...    _F7mv66u
#
#    sentence_seq_number      author  page    year          title  \
# 0                    4  Streissler   NaN  1972.0  Unknown Title
# 1                   10      Menger   NaN  1981.0  Unknown Title
# 2                   10         NaN  49.0  1871.0  Unknown Title
# ...

# %%
refs_df['author'].value_counts().head(100)
# Out:
# author
# Mises         9007
# Hayek         6823
# Kirzner       3230
# Rothbard      2782
# Schumpeter    2165
#               ...
# Clark          257
# Martin         255
# Bagus          251
# Higgs          250
# Storr          250
# Name: count, Length: 100, dtype: int64
