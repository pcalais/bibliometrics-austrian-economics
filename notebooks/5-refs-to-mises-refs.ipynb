# %%
import pandas as pd

refs_df = pd.read_csv("../data/processed/refs.csv")

refs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287818 entries, 0 to 287817
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           287818 non-null  int64
#  1   paper_id             287818 non-null  int64
#  2   raw                  287697 non-null  object
#  3   context              287818 non-null  object
#  4   sentence_id          287818 non-null  object
#  5   sentence_seq_number  287818 non-null  int64
#  6   author               218848 non-null  object
#  7   page                 55555 non-null   float64
#  8   year                 218646 non-null  float64
#  9   title                287818 non-null  object
#  10  filename             287818 non-null  object
#  11  sentence_count       287818 non-null  int64
#  12  reference_count      287818 non-null  int64
#  13  Source title         150006 non-null  object
#  14  DOI                  149583 non-null  object
#  15  Link                 150006 non-null  object
#  16  Author Keywords      115520 non-null  object
#  17  Publisher            109984 non-null  object
#  18  Open Access          46051 non-null   object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 41.7+ MB

# %%
mises_refs_df = refs_df[refs_df.author == 'Mises'].sort_values(by='page')

mises_refs_df.head(100)
# Out:
#         Unnamed: 0  paper_id  \
# 279406      279406      2258
# 116549      116549      1073
# 279364      279364      2258
# 254368      254368      2132
# 218888      218888      1740
# ...            ...       ...
# 199429      199429      1590
# 55531        55531       497
# 207844      207844      1627
# 55463        55463       497
# 55467        55467       497
#
#                                                       raw  \
# 279406                                 Mises, 1944: 1-19)
# 116549                                      (Mises, 19491
# 279364                                 Mises (1944: 1-19)
# 254368                              Mises, 1949, pp.1-71)
# 218888                     (Mises, [ ] 2007, p. 1), p. 1)
# ...                                                   ...
# 199429                                (Mises, 1978, p. 6)
# 55531                             (Mises [ ] 1966, 6), 6)
# 207844                                  Mises (1962, p. 6
# 55463                                     (Mises 1962, 6)
# 55467   (Mises [ ] 1958, 6, italics added), 6, italics...
#
#                                                   context sentence_id  \
# 279406  (Lippmann, 1938(Lippmann, /1943: 263;: 263; em...    _WpcSVk3
# 116549  Such a conclusion seems warranted from the fac...    _TbhKwuj
# 279364  Indeed, Mises (1944: 1-19) explicitly cites th...    _hqXcvq9
# 254368  Utilising the theory of human action developed...    _6pNjGwA
# 218888  Abstaining from explicitly articulating any me...    _2MN3vn2
# ...                                                   ...         ...
# 199429  Economic synthetic a priori judgements are, in...    _NbD5kjZ
# 55531   Finally, Mises concludes: 'It is a mistake to ...    _xE332wC
# 207844  One such necessary synthetic truth, Mises (196...    _9epFByv
# 55463   The germs were real because they conditioned t...    _ZFcKDHD
# 55467   Indeed, the postulated existence of a regulari...    _8adubE8
#
#         sentence_seq_number author  page    year  \
# 279406                 3456  Mises   1.0  1944.0
# 116549                  187  Mises   1.0  1949.0
# 279364                 3399  Mises   1.0  1944.0
# 254368                   39  Mises   1.0  1949.0
# 218888                  303  Mises   1.0  2007.0
# ...                     ...    ...   ...     ...
# 199429                  236  Mises   6.0  1978.0
# 55531                   124  Mises   6.0  1966.0
# 207844                   31  Mises   6.0  1962.0
# 55463                    31  Mises   6.0  1962.0
# 55467                    38  Mises   6.0  1958.0
#
#                                                     title  \
# 279406                        THE DARK SIDE OF MANAGEMENT
# 116549  Beauty and the Beholder: The Pursuit of Beauty...
# 279364                        THE DARK SIDE OF MANAGEMENT
# 254368  China's economic transformation in the evoluti...
# 218888  Determinism, free will, and the Austrian Schoo...
# ...                                                   ...
# 199429  A NEO-KANTIAN CRITIQUE OF VON MISES'S EPISTEMO...
# 55531   Ludwig von Mises on the epistemological founda...
# 207844  Decentralizing corporate governance? A praxeol...
# 55463   Ludwig von Mises on the epistemological founda...
# 55467   Ludwig von Mises on the epistemological founda...
#
#                                                  filename  sentence_count  \
# 279406           10.4324.9781315754581.pdf.grobid.tei.xml            3855
# 116549          10.1002.mar.4220100603.pdf.grobid.tei.xml             370
# 279364           10.4324.9781315754581.pdf.grobid.tei.xml            3855
# 254368      10.1504.ijepee.2007.015579.pdf.grobid.tei.xml             346
# 218888   10.1080.1350178X.2021.1926528.pdf.grobid.tei.xml             496
# ...                                                   ...             ...
# 199429       10.1017.S0266267100003710.pdf.grobid.tei.xml             288
# 55531   Ludwig-von-Mises-on-the-epistemological-founda...             533
# 207844      10.1057.s41310-022-00151-7.pdf.grobid.tei.xml             466
# 55463   Ludwig-von-Mises-on-the-epistemological-founda...             533
# 55467   Ludwig-von-Mises-on-the-epistemological-founda...             533
#
#         reference_count                                       Source title  \
# 279406              337                                                NaN
# 116549               69                             Psychology & Marketing
# 279364              337                                                NaN
# 254368               43                                                NaN
# 218888               91                    Journal of Economic Methodology
# ...                 ...                                                ...
# 199429               18                           Economics and Philosophy
# 55531                66                       Review of Austrian Economics
# 207844              121  International Journal of Disclosure and Govern...
# 55463                66                       Review of Austrian Economics
# 55467                66                       Review of Austrian Economics
#
#                                   DOI  \
# 279406                            NaN
# 116549         10.1002/mar.4220100603
# 279364                            NaN
# 254368                            NaN
# 218888  10.1080/1350178X.2021.1926528
# ...                               ...
# 199429      10.1017/S0266267100003710
# 55531       10.1007/s11138-008-0046-4
# 207844     10.1057/s41310-022-00151-7
# 55463       10.1007/s11138-008-0046-4
# 55467       10.1007/s11138-008-0046-4
#
#                                                      Link  \
# 279406                                                NaN
# 116549  https://www.scopus.com/inward/record.uri?eid=2...
# 279364                                                NaN
# 254368                                                NaN
# 218888  https://www.scopus.com/inward/record.uri?eid=2...
# ...                                                   ...
# 199429  https://www.scopus.com/inward/record.uri?eid=2...
# 55531   https://www.scopus.com/inward/record.uri?eid=2...
# 207844  https://www.scopus.com/inward/record.uri?eid=2...
# 55463   https://www.scopus.com/inward/record.uri?eid=2...
# 55467   https://www.scopus.com/inward/record.uri?eid=2...
#
#                                           Author Keywords           Publisher  \
# 279406                                                NaN                 NaN
# 116549                                                NaN                 NaN
# 279364                                                NaN                 NaN
# 254368                                                NaN                 NaN
# 218888  Austrian School of Economics; compatibilism; D...           Routledge
# ...                                                   ...                 ...
# 199429                                                NaN                 NaN
# 55531   Austrian economics; Epistemology; Ludwig von M...                 NaN
# 207844  Agency theory; Corporate governance; Knowledge...  Palgrave Macmillan
# 55463   Austrian economics; Epistemology; Ludwig von M...                 NaN
# 55467   Austrian economics; Epistemology; Ludwig von M...                 NaN
#
#                                      Open Access
# 279406                                       NaN
# 116549                                       NaN
# 279364                                       NaN
# 254368                                       NaN
# 218888                                       NaN
# ...                                          ...
# 199429                                       NaN
# 55531                                        NaN
# 207844  All Open Access; Hybrid Gold Open Access
# 55463                                        NaN
# 55467                                        NaN
#
# [100 rows x 19 columns]

# %%
import pandas as pd

# Lê o arquivo assumindo que é separado por vírgulas
human_action_page_ranges_df = pd.read_csv("chapter-ranges/human-action-page-to-chapter.txt")

human_action_page_ranges_df.head()
# Out:
#    start_page  end_page  chapter
# 0           1        11        0
# 1          11        30        1
# 2          30        72        2
# 3          72        92        3
# 4          92        99        4

# %%
def get_human_action_chapter_by_page(page):
    row = human_action_page_ranges_df[
        (human_action_page_ranges_df['start_page'] <= page) &
        (human_action_page_ranges_df['end_page'] >= page)
    ]
    if not row.empty:
        return int(row.iloc[0]['chapter'])
    else:
        return None  # ou você pode retornar "Desconhecido", -1, etc.

assert get_human_action_chapter_by_page(111)

# %%
mises_refs_df['human_action_chapter_by_ref_page'] = mises_refs_df['page'].apply(get_human_action_chapter_by_page)
mises_refs_df['human_action_chapter_number'] = mises_refs_df['human_action_chapter_by_ref_page']

# %%
chapter_to_part_df = pd.read_csv("chapter-ranges/chapter-to-part.csv")

chapter_to_part_df.head()
# Out:
#    human_action_chapter_number  \
# 0                            0
# 1                            1
# 2                            2
# 3                            3
# 4                            4
#
#                            human_action_chapter_name  \
# 0                            Chapter 0: Introduction
# 1                              Chapter 1: Acting Man
# 2  Chapter 2: The Epistemological Problems of the...
# 3  Chapter 3: Economics and the Revolt Against Re...
# 4  Chapter 4: A First Analysis of the Category of...
#
#    human_action_part_number human_action_part_name
# 0                         1   Part 1: Human Action
# 1                         1   Part 1: Human Action
# 2                         1   Part 1: Human Action
# 3                         1   Part 1: Human Action
# 4                         1   Part 1: Human Action

# %%
import pandas as pd

# Exemplo de join usando merge
mises_refs_df = pd.merge(
    mises_refs_df,
    chapter_to_part_df,
    left_on='human_action_chapter_number',
    right_on='human_action_chapter_number',
    how='left'  # ou 'inner', 'right', 'outer', dependendo do seu objetivo
)

# %%
mises_refs_df.to_csv("../data/processed/mises_refs.csv")
