# %%
import pandas as pd 

papers_df = pd.read_csv("../data/processed/papers.csv")

# %%
papers_df.head()
# Out:
#    Unnamed: 0  paper_id                                              title  \
# 0        1107        47                                      Unknown Title
# 1         663       662                                      Unknown Title
# 2        2269      1205                                      Unknown Title
# 3        2272      1208  NEW HORIZONS IN INSTITUTIONAL AND EVOLUTIONARY...
# 4        2280      1216                                      Unknown Title
#
#                                             filename  sentence_count  \
# 0       10.1007.978-3-030-45081-6.pdf.grobid.tei.xml            5053
# 1  References_2012_Edward-Elgar-Publishing-Ltd.pd...              88
# 2     10.4337.9781781009055.00031.pdf.grobid.tei.xml              87
# 3           10.4337.9781782548362.pdf.grobid.tei.xml           10003
# 4           10.4337.9781849809634.pdf.grobid.tei.xml            3728
#
#    reference_count Source title  DOI Link Author Keywords Publisher  \
# ...

# %%
papers_df['Source title'].value_counts()
# Out:
# Source title
# Review of Austrian Economics                         292
# Quarterly Journal of Austrian Economics               27
# Journal of Business Ethics                            19
# Public Choice                                         19
# Small Business Economics                              15
#                                                     ...
# Industrial and Corporate Change                        1
# Computer Standards and Interfaces                      1
# Journal of Business Venturing Insights                 1
# Environment and Planning C: Government and Policy      1
# Current Opinion in Hematology                          1
# Name: count, Length: 236, dtype: int64
