# %%
import pandas as pd 

papers_df = pd.read_csv("../data/processed/papers.csv")

# %%
papers_df.head()
# Out:
#    paper_id                                              title  \
# 0      2458  Young Mr. Mises and younger historicists: orig...
# 1      2457          You have nothing to lose but your chains?
# 2      2456                                      Unknown Title
# 3      2455                                      Unknown Title
# 4      2454                                      Unknown Title
#
#                                             filename  sentence_count  \
# 0  Young-Mr-Mises-and-younger-historicists-origin...             263
# 1  You-have-nothing-to-lose-but-your-chains_2024_...             350
# 2  Workers-as-lifeentrepreneurs_2017_Centre-for-S...             387
# 3  Word-Action-and-Entrepreneurship_2019_Sciendo....             113
# 4  Word-Action-and-Entrepreneurship_2019_Sciendo ...             113
#
#    reference_count                                       source title  \
# 0               52  The Origins of Neoliberalism: Insights from Ec...
# ...

# %%
na_percent = papers_df.isna().mean().mul(100).round(2)
print(na_percent)
# Out:
# paper_id           0.0
# title              0.0
# filename           0.0
# sentence_count     0.0
# reference_count    0.0
# source title       0.0
# similarity         0.0
# dtype: float64

# %%
papers_df['source title'].value_counts()
# Out:
# source title
# Review of Austrian Economics                                  853
# Quarterly Journal of Austrian Economics                       113
# Journal des Economistes et des Etudes Humaines                 41
# Journal of Business Ethics                                     30
# Small Business Economics                                       26
#                                                              ...
# Applied Evolutionary Economics and Complex Systems              1
# Revista de Gestao Social e Ambiental                            1
# Asian Journal of Law and Economics                              1
# Capitalism in the 21st Century: Through the Prism of Value      1
# The Palgrave Handbook of the History of Human Sciences          1
# Name: count, Length: 652, dtype: int64
